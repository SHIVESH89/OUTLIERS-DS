# %%
#AI/ML UNIVARIATE ANALYSIS

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
d=pd.read_csv('StudentPerformanceFactors.csv')

# %%
d.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
d.drop(columns=(['Gender','Learning_Disabilities','Peer_Influence',
                 'Parental_Education_Level','Distance_from_Home','School_Type','Teacher_Quality','Family_Income',
                 'Internet_Access','Sleep_Hours','Parental_Involvement','Hours_Studied',
                 'Attendance','Access_to_Resources','Extracurricular_Activities',
                'Previous_Scores','Motivation_Level','Tutoring_Sessions','Physical_Activity']))
# Out:
#       Exam_Score
# 0             67
# 1             61
# 2             74
# 3             71
# 4             70
# ...          ...
# 6602          68
# 6603          69
# 6604          68
# 6605          68
# 6606          64
#
# [6607 rows x 1 columns]

# %%
d.describe()['Exam_Score'] #central tendancy
# Out:
# count    6607.000000
# mean       67.235659
# std         3.890456
# min        55.000000
# 25%        65.000000
# 50%        67.000000
# 75%        69.000000
# max       101.000000
# Name: Exam_Score, dtype: float64

# %%
fig1=px.histogram(d,x='Exam_Score')

# %%
fig1.show()

# %%
fig2=px.box(d,y='Exam_Score')

# %%
fig2.show()
